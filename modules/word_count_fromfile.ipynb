# %%
from collections import Counter
import re  #with RegEx

# Open file and read content
with open("data.txt", "r") as file:
    text = file.read().lower()   # Convert to lowercase

# Remove punctuation
text = re.sub(r"[^\w\s]", "", text)

# Split into words
words = text.split()

# Count word frequency
word_count = Counter(words)

print("Duplicate words in the file:\n")

# Print words appearing more than once
for word, count in word_count.items():
    if count > 1:
        print(f"{word} -> {count} times")
# Out:
# Duplicate words in the file:
#
# python -> 4 times
# is -> 3 times
# powerful -> 2 times
# and -> 3 times
# learning -> 2 times

# %%
# without RegEx
from collections import Counter

# Open file and read content
with open("data.txt", "r") as file:
    text = file.read().lower()   # Convert to lowercase



# Split into words
words = text.split()

# Count word frequency
word_count = Counter(words)

print("Duplicate words in the file:\n")

# Print words appearing more than once
for word, count in word_count.items():
    if count > 1:
        print(f"{word} -> {count} times")
# Out:
# Duplicate words in the file:
#
# python -> 4 times
# is -> 3 times
# powerful -> 2 times
# and -> 3 times
# learning -> 2 times
